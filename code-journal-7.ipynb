# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,1,100)

def f(x):
    return exp(x)

# %%
y = np.exp(x)
plt.plot(x,y,color="pink")
plt.xlabel('Time (milliseconds)')
plt.ylabel('Awesomeness')
plt.savefig('code-journal-7.png',bbox_inches="tight",facecolor="pink")
