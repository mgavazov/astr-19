# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Creating random data using bytes

x = np.random.permutation(1000)

#ploting histogram

plt.hist(x, bins=100, width=0.1, color='lightsalmon', edgecolor='orangered')
plt.ylabel("Rando")
plt.xlabel("X")
plt.savefig("code-journal-10.pdf",bbox_inches="tight",facecolor="mistyrose")
