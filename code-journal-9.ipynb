# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Creating random data

x = np.random.uniform(0,1,1000)

#creating histogram bins
bins = 100
width = 0.1

plt.hist(x, bins=100,width=0.5, color='lavender', edgecolor="indigo")
plt.ylabel("N per bins")
plt.xlabel("X")
plt.savefig("code-journal-9.pdf",bbox_inches="tight",facecolor="white")
